# %% [markdown]
# ## Act_report
# *By Francis Wobulu Wesa*
#
# ### Analyzing and Visualization
# WeRateDogs is a Twitter	account	that rates people's	dogs. Ideally the dogs are supposed to be rated out of 10 but alas we do have some ratings that are above that and thats alright cause all dogs deserve a 10 and some more than that.
#
# The rating has enabled me to come up with various insights from the data set, like, which dog type is most common, the dog with the hihest average rating and one with the lowest average rating.
#
# ### Most common dog_type.
# The golden retriever is the most common dogtype from the dataset based on valu counts.
#
# ![15%20most%20often%20rated%20dog%20breeds.png](attachment:15%20most%20often%20rated%20dog%20breeds.png)
#
# - Here is an example of the cute fluffy dog, you can clearly see why it's a favourite among people.
#
#
# <div>
# <img src="attachment:C-3wvtxXcAUTuBE.jpg" width="100"/>
# </div>
#
#
# ### Retweet count and Favorite count
#
# The retweet count and favorite count of the tweets in the data set showed a positive relationship
#
# ![scatter%20plot%20%282%29.png](attachment:scatter%20plot%20%282%29.png)
